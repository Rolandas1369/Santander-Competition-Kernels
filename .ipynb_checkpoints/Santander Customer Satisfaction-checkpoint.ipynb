# %% [markdown]
# <h1>Santander Customer Satisfaction</h1>
# <p>Which customers are happy customers</p>
#
# <p>From frontline support teams to C-suites, customer satisfaction is a key measure of success. Unhappy customers don't stick around. What's more, unhappy customers rarely voice their dissatisfaction before leaving.
#
# Santander Bank is asking Kagglers to help them identify dissatisfied customers early in their relationship. Doing so would allow Santander to take proactive steps to improve a customer's happiness before it's too late.
#
# In this competition, you'll work with hundreds of anonymized features to predict if a customer is satisfied or dissatisfied with their banking experience.</p>

# %% [markdown]
# <h3>Import needed imports</h3>

# %%
# %%time
import os
import numpy as np 
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import ensemble
from sklearn import neighbors
from sklearn import linear_model
import xgboost as xgb

import matplotlib.pyplot as plt

from sklearn import preprocessing

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline

from sklearn.metrics import roc_auc_score

import warnings
warnings.filterwarnings('ignore')
# Out:
# CPU times: user 1.77 s, sys: 411 ms, total: 2.18 s
# Wall time: 8.05 s

# %% [markdown]
# <h3>Importing needed files</h3>

# %%
# %%time
#load data
test_data = pd.read_csv('input/test.csv')
train_data = pd.read_csv('input/train.csv')
# Out:
# CPU times: user 5.64 s, sys: 392 ms, total: 6.03 s
# Wall time: 6.32 s

# %% [markdown]
# <h3>Make sample of dataset for faster interaction</h3>

# %%
train_data = train_data.sample(n=5000)
train_data.shape
# Out:
# (5000, 371)

# %% [markdown]
# <h3>Lets look at first 5 rows</h3>

# %%
# How data looks
train_data.head()
# Out:
#            ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 65954  131692     2     23                 0.0                      0.0
# 20649   41361     2     36                 0.0                      0.0
# 29884   59757     2     23                 0.0                      0.0
# 63513  126824     2     23                 0.0                      0.0
# 6205    12477     2     24                 0.0                      0.0
#
#        imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  \
# 65954                      0.0                      0.0
# 20649                      0.0                      0.0
# 29884                      0.0                      0.0
# 63513                      0.0                      0.0
# 6205                       0.0                      0.0
#
#        imp_op_var40_comer_ult3  imp_op_var40_efect_ult1  \
# 65954                      0.0                      0.0
# 20649                      0.0                      0.0
# 29884                      0.0                      0.0
# 63513                      0.0                      0.0
# 6205                       0.0                      0.0
#
#        imp_op_var40_efect_ult3  ...  saldo_medio_var33_hace2  \
# 65954                      0.0  ...                      0.0
# 20649                      0.0  ...                      0.0
# 29884                      0.0  ...                      0.0
# 63513                      0.0  ...                      0.0
# 6205                       0.0  ...                      0.0
#
#        saldo_medio_var33_hace3  saldo_medio_var33_ult1  \
# 65954                      0.0                     0.0
# 20649                      0.0                     0.0
# 29884                      0.0                     0.0
# 63513                      0.0                     0.0
# 6205                       0.0                     0.0
#
#        saldo_medio_var33_ult3  saldo_medio_var44_hace2  \
# 65954                     0.0                      0.0
# 20649                     0.0                      0.0
# 29884                     0.0                      0.0
# 63513                     0.0                      0.0
# 6205                      0.0                      0.0
#
#        saldo_medio_var44_hace3  saldo_medio_var44_ult1  \
# 65954                      0.0                     0.0
# 20649                      0.0                     0.0
# 29884                      0.0                     0.0
# 63513                      0.0                     0.0
# 6205                       0.0                     0.0
#
#        saldo_medio_var44_ult3          var38  TARGET
# 65954                     0.0   57347.070000       0
# 20649                     0.0   34452.450000       0
# 29884                     0.0   80455.770000       0
# 63513                     0.0  150720.270000       0
# 6205                      0.0  117310.979016       0
#
# [5 rows x 371 columns]

# %% [markdown]
# <p>Dataset has a lot 0 values<p>

# %% [markdown]
# <h3>Does dataset has empty or nan values?</h3>

# %%
# %time
# Any nulls?
(train_data.isnull().sum()).any() > 0
# Out:
# CPU times: user 10 µs, sys: 1e+03 ns, total: 11 µs
# Wall time: 21 µs
# False

# %% [markdown]
# <h3>We dont need rows that contains only 0 let`s drop them</h3>

# %%
# %time
# Drop columns what contains 0 only
dropable_cols = []
for i in train_data.columns:
    if (train_data[i] == 0).all():
        dropable_cols.append(i)
        
train_data.drop(dropable_cols, axis=1, inplace=True)
test_data.drop(dropable_cols, axis=1, inplace=True)
print("Data shape after droping rows: ")
print("Train data shape: ",train_data.shape, "Test data shape: ", test_data.shape)
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 10 µs
# Data shape after droping rows:
# Train data shape:  (5000, 280) Test data shape:  (75818, 279)

# %% [markdown]
# <h3>Highly corelated columns can make less accurate predictions, let`s drop them</h3>

# %%
# %%time
# Removing dublicated columns
columns_to_drop = []
columns = train_data.columns
for i in range(len(columns) - 1):
    # assign and check column equality 
    column_to_check = train_data[columns[i]]
    for c in range(i+1, len(columns)):
        if np.array_equal(column_to_check, train_data[columns[c]].values):
            columns_to_drop.append(columns[c])
train_data.drop(columns_to_drop, axis=1, inplace=True)
test_data.drop(columns_to_drop, axis=1, inplace=True)
print("Data after cleaning")
print("Train data shape: ",train_data.shape, "Test data shape: ", test_data.shape)
# Out:
# Data after cleaning
# Train data shape:  (5000, 252) Test data shape:  (75818, 251)
# CPU times: user 3.91 s, sys: 44.4 ms, total: 3.95 s
# Wall time: 3.95 s

# %%
### Hard Chalange###
train_data.corr()
# Out:
#                                      ID      var3     var15  \
# ID                             1.000000 -0.006524 -0.008021
# var3                          -0.006524  1.000000 -0.019229
# var15                         -0.008021 -0.019229  1.000000
# imp_ent_var16_ult1            -0.002722  0.005593  0.061632
# imp_op_var39_comer_ult1        0.002047  0.010530  0.104967
# imp_op_var39_comer_ult3        0.004455  0.010591  0.116510
# imp_op_var40_comer_ult1       -0.035798  0.001269  0.050848
# imp_op_var40_comer_ult3       -0.035851  0.001291  0.055198
# imp_op_var40_efect_ult1       -0.022529  0.001009  0.004373
# imp_op_var40_ult1             -0.039346  0.001466  0.043716
# imp_op_var41_comer_ult1        0.016552  0.010965  0.094011
# imp_op_var41_comer_ult3        0.018229  0.011005  0.105744
# imp_op_var41_efect_ult1       -0.020114 -0.020643  0.092177
# imp_op_var41_efect_ult3       -0.015583 -0.016333  0.107119
# imp_op_var41_ult1             -0.004424 -0.007729  0.113088
# imp_op_var39_efect_ult1       -0.023465 -0.018696  0.085466
# imp_op_var39_efect_ult3       -0.018480 -0.015521  0.103513
# imp_op_var39_ult1             -0.014452 -0.006859  0.117430
# imp_sal_var16_ult1             0.005415  0.001643  0.019632
# ind_var1_0                    -0.008591  0.005035  0.112806
# ind_var1                      -0.032171  0.003040  0.065239
# ind_var5_0                     0.004460 -0.010456 -0.080188
# ind_var5                       0.019064  0.051239 -0.072757
# ind_var8_0                    -0.000582  0.009284  0.078676
# ind_var8                      -0.009968  0.008743  0.078214
# ind_var12_0                    0.003616  0.013272  0.278764
# ind_var12                      0.008632  0.010677  0.215299
# ind_var13_0                   -0.007594  0.011585  0.299318
# ind_var13_corto_0             -0.002536  0.010495  0.241773
# ind_var13_corto               -0.006608  0.010318  0.242374
# ...                                 ...       ...       ...
# saldo_medio_var8_ult1         -0.000320  0.004450  0.057609
# saldo_medio_var8_ult3         -0.003303  0.004135  0.056122
# saldo_medio_var12_hace2        0.003594  0.003990  0.143076
# saldo_medio_var12_hace3        0.026528  0.003443  0.130848
# saldo_medio_var12_ult1         0.009899  0.005036  0.173912
# saldo_medio_var12_ult3         0.013475  0.005341  0.181154
# saldo_medio_var13_corto_hace2 -0.007894  0.007079  0.198544
# saldo_medio_var13_corto_hace3 -0.012255  0.003660  0.097673
# saldo_medio_var13_corto_ult1  -0.004765  0.007567  0.218944
# saldo_medio_var13_corto_ult3  -0.004270  0.007477  0.214653
# saldo_medio_var13_largo_hace2 -0.005396  0.002773  0.128526
# saldo_medio_var13_largo_hace3  0.008214  0.001492  0.065080
# saldo_medio_var13_largo_ult1   0.004129  0.003174  0.135232
# saldo_medio_var13_largo_ult3   0.002884  0.003113  0.130655
# saldo_medio_var13_medio_hace2 -0.012725  0.000694  0.005368
# saldo_medio_var13_medio_ult3  -0.012725  0.000694  0.005368
# saldo_medio_var17_hace2       -0.003041  0.000865  0.060159
# saldo_medio_var17_hace3        0.024274  0.000889  0.018090
# saldo_medio_var17_ult1         0.003308  0.000813  0.011586
# saldo_medio_var17_ult3         0.002439  0.000841  0.015677
# saldo_medio_var33_hace2        0.000732  0.000772  0.036132
# saldo_medio_var33_hace3        0.001018  0.000716  0.034025
# saldo_medio_var33_ult1        -0.003391  0.000999  0.043951
# saldo_medio_var33_ult3        -0.002944  0.001008  0.044511
# saldo_medio_var44_hace2       -0.023540  0.000729  0.016390
# saldo_medio_var44_hace3       -0.023540  0.000729  0.016390
# saldo_medio_var44_ult1        -0.027520  0.000976  0.029779
# saldo_medio_var44_ult3        -0.027959  0.001018  0.032479
# var38                          0.007020  0.000151 -0.000726
# TARGET                        -0.019668  0.010090  0.095293
#
#                                imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# ID                                      -0.002722                 0.002047
# var3                                     0.005593                 0.010530
# var15                                    0.061632                 0.104967
# imp_ent_var16_ult1                       1.000000                 0.110708
# imp_op_var39_comer_ult1                  0.110708                 1.000000
# imp_op_var39_comer_ult3                  0.102246                 0.906816
# imp_op_var40_comer_ult1                  0.110994                 0.397974
# imp_op_var40_comer_ult3                  0.084078                 0.365801
# imp_op_var40_efect_ult1                 -0.001479                 0.008400
# imp_op_var40_ult1                        0.082766                 0.322856
# imp_op_var41_comer_ult1                  0.076203                 0.930212
# imp_op_var41_comer_ult3                  0.079480                 0.846874
# imp_op_var41_efect_ult1                  0.053571                 0.376210
# imp_op_var41_efect_ult3                  0.056980                 0.398074
# imp_op_var41_ult1                        0.086005                 0.686811
# imp_op_var39_efect_ult1                  0.048774                 0.346711
# imp_op_var39_efect_ult3                  0.054467                 0.383450
# imp_op_var39_ult1                        0.102279                 0.728205
# imp_sal_var16_ult1                       0.009790                 0.069373
# ind_var1_0                               0.100225                 0.197638
# ind_var1                                 0.085223                 0.272039
# ind_var5_0                              -0.003639                -0.191768
# ind_var5                                 0.056731                 0.038494
# ind_var8_0                               0.009415                 0.200641
# ind_var8                                 0.012468                 0.216786
# ind_var12_0                              0.043852                 0.020858
# ind_var12                                0.063470                 0.037905
# ind_var13_0                              0.002000                -0.012938
# ind_var13_corto_0                        0.006348                -0.024438
# ind_var13_corto                          0.007240                -0.023754
# ...                                           ...                      ...
# saldo_medio_var8_ult1                    0.016852                 0.206278
# saldo_medio_var8_ult3                    0.017401                 0.187272
# saldo_medio_var12_hace2                  0.009107                 0.032095
# saldo_medio_var12_hace3                 -0.007711                 0.010132
# saldo_medio_var12_ult1                   0.024698                 0.041451
# saldo_medio_var12_ult3                   0.030873                 0.047866
# saldo_medio_var13_corto_hace2           -0.014014                -0.027172
# saldo_medio_var13_corto_hace3           -0.007792                -0.013309
# saldo_medio_var13_corto_ult1            -0.015342                -0.029235
# saldo_medio_var13_corto_ult3            -0.015194                -0.028852
# saldo_medio_var13_largo_hace2           -0.006391                 0.004492
# saldo_medio_var13_largo_hace3           -0.003368                -0.005058
# saldo_medio_var13_largo_ult1            -0.007006                 0.000300
# saldo_medio_var13_largo_ult3            -0.006792                -0.001724
# saldo_medio_var13_medio_hace2           -0.001613                 0.051833
# saldo_medio_var13_medio_ult3            -0.001613                 0.051833
# saldo_medio_var17_hace2                 -0.002012                -0.002147
# saldo_medio_var17_hace3                 -0.002068                -0.001579
# saldo_medio_var17_ult1                  -0.001891                -0.002917
# saldo_medio_var17_ult3                  -0.001957                -0.003315
# saldo_medio_var33_hace2                 -0.001744                -0.003273
# saldo_medio_var33_hace3                 -0.001613                -0.003028
# saldo_medio_var33_ult1                  -0.002290                -0.004300
# saldo_medio_var33_ult3                  -0.002305                -0.004328
# saldo_medio_var44_hace2                 -0.001613                -0.003028
# saldo_medio_var44_hace3                 -0.001613                -0.003028
# saldo_medio_var44_ult1                  -0.002193                -0.004117
# saldo_medio_var44_ult3                  -0.002293                -0.004304
# var38                                   -0.003075                 0.024544
# TARGET                                  -0.019536                -0.001839
#
#                                imp_op_var39_comer_ult3  \
# ID                                            0.004455
# var3                                          0.010591
# var15                                         0.116510
# imp_ent_var16_ult1                            0.102246
# imp_op_var39_comer_ult1                       0.906816
# imp_op_var39_comer_ult3                       1.000000
# imp_op_var40_comer_ult1                       0.385946
# imp_op_var40_comer_ult3                       0.389934
# imp_op_var40_efect_ult1                       0.004658
# imp_op_var40_ult1                             0.325530
# imp_op_var41_comer_ult1                       0.833507
# imp_op_var41_comer_ult3                       0.938927
# imp_op_var41_efect_ult1                       0.328753
# imp_op_var41_efect_ult3                       0.401561
# imp_op_var41_ult1                             0.576733
# imp_op_var39_efect_ult1                       0.302377
# imp_op_var39_efect_ult3                       0.386212
# imp_op_var39_ult1                             0.625747
# imp_sal_var16_ult1                            0.078301
# ind_var1_0                                    0.205269
# ind_var1                                      0.264754
# ind_var5_0                                   -0.180140
# ind_var5                                      0.037077
# ind_var8_0                                    0.169612
# ind_var8                                      0.184046
# ind_var12_0                                   0.023307
# ind_var12                                     0.044060
# ind_var13_0                                  -0.015172
# ind_var13_corto_0                            -0.031471
# ind_var13_corto                              -0.030732
# ...                                                ...
# saldo_medio_var8_ult1                         0.179906
# saldo_medio_var8_ult3                         0.159043
# saldo_medio_var12_hace2                       0.034806
# saldo_medio_var12_hace3                       0.008083
# saldo_medio_var12_ult1                        0.039443
# saldo_medio_var12_ult3                        0.044673
# saldo_medio_var13_corto_hace2                -0.027846
# saldo_medio_var13_corto_hace3                -0.012976
# saldo_medio_var13_corto_ult1                 -0.030081
# saldo_medio_var13_corto_ult3                 -0.029659
# saldo_medio_var13_largo_hace2                 0.012039
# saldo_medio_var13_largo_hace3                -0.004403
# saldo_medio_var13_largo_ult1                  0.006502
# saldo_medio_var13_largo_ult3                  0.003415
# saldo_medio_var13_medio_hace2                 0.031254
# saldo_medio_var13_medio_ult3                  0.031254
# saldo_medio_var17_hace2                      -0.002775
# saldo_medio_var17_hace3                      -0.002460
# saldo_medio_var17_ult1                       -0.003170
# saldo_medio_var17_ult3                       -0.003466
# saldo_medio_var33_hace2                      -0.003288
# saldo_medio_var33_hace3                      -0.003042
# saldo_medio_var33_ult1                       -0.004319
# saldo_medio_var33_ult3                       -0.004348
# saldo_medio_var44_hace2                      -0.003042
# saldo_medio_var44_hace3                      -0.003042
# saldo_medio_var44_ult1                       -0.004136
# saldo_medio_var44_ult3                       -0.004324
# var38                                         0.025798
# TARGET                                       -0.000662
#
#                                imp_op_var40_comer_ult1  \
# ID                                           -0.035798
# var3                                          0.001269
# var15                                         0.050848
# imp_ent_var16_ult1                            0.110994
# imp_op_var39_comer_ult1                       0.397974
# imp_op_var39_comer_ult3                       0.385946
# imp_op_var40_comer_ult1                       1.000000
# imp_op_var40_comer_ult3                       0.941768
# imp_op_var40_efect_ult1                       0.005403
# imp_op_var40_ult1                             0.826481
# imp_op_var41_comer_ult1                       0.033495
# imp_op_var41_comer_ult3                       0.066677
# imp_op_var41_efect_ult1                       0.038893
# imp_op_var41_efect_ult3                       0.036063
# imp_op_var41_ult1                             0.044486
# imp_op_var39_efect_ult1                       0.036855
# imp_op_var39_efect_ult3                       0.035463
# imp_op_var39_ult1                             0.258186
# imp_sal_var16_ult1                           -0.000866
# ind_var1_0                                    0.252064
# ind_var1                                      0.418388
# ind_var5_0                                   -0.013071
# ind_var5                                      0.010524
# ind_var8_0                                    0.009230
# ind_var8                                      0.010332
# ind_var12_0                                   0.049793
# ind_var12                                     0.062672
# ind_var13_0                                   0.035541
# ind_var13_corto_0                             0.006038
# ind_var13_corto                               0.006312
# ...                                                ...
# saldo_medio_var8_ult1                         0.006824
# saldo_medio_var8_ult3                         0.008150
# saldo_medio_var12_hace2                       0.053971
# saldo_medio_var12_hace3                      -0.001809
# saldo_medio_var12_ult1                        0.078554
# saldo_medio_var12_ult3                        0.090493
# saldo_medio_var13_corto_hace2                -0.003460
# saldo_medio_var13_corto_hace3                -0.001746
# saldo_medio_var13_corto_ult1                 -0.003035
# saldo_medio_var13_corto_ult3                 -0.002839
# saldo_medio_var13_largo_hace2                 0.043164
# saldo_medio_var13_largo_hace3                 0.002601
# saldo_medio_var13_largo_ult1                  0.034679
# saldo_medio_var13_largo_ult3                  0.028213
# saldo_medio_var13_medio_hace2                 0.000597
# saldo_medio_var13_medio_ult3                  0.000597
# saldo_medio_var17_hace2                      -0.000456
# saldo_medio_var17_hace3                      -0.000468
# saldo_medio_var17_ult1                       -0.000428
# saldo_medio_var17_ult3                       -0.000443
# saldo_medio_var33_hace2                      -0.000395
# saldo_medio_var33_hace3                      -0.000365
# saldo_medio_var33_ult1                       -0.000519
# saldo_medio_var33_ult3                       -0.000522
# saldo_medio_var44_hace2                      -0.000365
# saldo_medio_var44_hace3                      -0.000365
# saldo_medio_var44_ult1                       -0.000497
# saldo_medio_var44_ult3                       -0.000519
# var38                                         0.003467
# TARGET                                       -0.003591
#
#                                imp_op_var40_comer_ult3  \
# ID                                           -0.035851
# var3                                          0.001291
# var15                                         0.055198
# imp_ent_var16_ult1                            0.084078
# imp_op_var39_comer_ult1                       0.365801
# imp_op_var39_comer_ult3                       0.389934
# imp_op_var40_comer_ult1                       0.941768
# imp_op_var40_comer_ult3                       1.000000
# imp_op_var40_efect_ult1                       0.003413
# imp_op_var40_ult1                             0.816750
# imp_op_var41_comer_ult1                       0.021741
# imp_op_var41_comer_ult3                       0.049242
# imp_op_var41_efect_ult1                       0.025097
# imp_op_var41_efect_ult3                       0.026247
# imp_op_var41_ult1                             0.028798
# imp_op_var39_efect_ult1                       0.023766
# imp_op_var39_efect_ult3                       0.025730
# imp_op_var39_ult1                             0.240935
# imp_sal_var16_ult1                           -0.000881
# ind_var1_0                                    0.256377
# ind_var1                                      0.411301
# ind_var5_0                                   -0.011635
# ind_var5                                      0.011417
# ind_var8_0                                    0.004434
# ind_var8                                      0.005268
# ind_var12_0                                   0.035639
# ind_var12                                     0.045749
# ind_var13_0                                   0.050084
# ind_var13_corto_0                             0.002083
# ind_var13_corto                               0.002298
# ...                                                ...
# saldo_medio_var8_ult1                         0.003725
# saldo_medio_var8_ult3                         0.004666
# saldo_medio_var12_hace2                       0.041038
# saldo_medio_var12_hace3                      -0.001840
# saldo_medio_var12_ult1                        0.059817
# saldo_medio_var12_ult3                        0.068965
# saldo_medio_var13_corto_hace2                -0.003614
# saldo_medio_var13_corto_hace3                -0.001840
# saldo_medio_var13_corto_ult1                 -0.003421
# saldo_medio_var13_corto_ult3                 -0.003274
# saldo_medio_var13_largo_hace2                 0.067785
# saldo_medio_var13_largo_hace3                 0.004447
# saldo_medio_var13_largo_ult1                  0.054961
# saldo_medio_var13_largo_ult3                  0.044955
# saldo_medio_var13_medio_hace2                 0.000269
# saldo_medio_var13_medio_ult3                  0.000269
# saldo_medio_var17_hace2                      -0.000464
# saldo_medio_var17_hace3                      -0.000476
# saldo_medio_var17_ult1                       -0.000436
# saldo_medio_var17_ult3                       -0.000451
# saldo_medio_var33_hace2                      -0.000402
# saldo_medio_var33_hace3                      -0.000372
# saldo_medio_var33_ult1                       -0.000528
# saldo_medio_var33_ult3                       -0.000531
# saldo_medio_var44_hace2                      -0.000372
# saldo_medio_var44_hace3                      -0.000372
# saldo_medio_var44_ult1                       -0.000505
# saldo_medio_var44_ult3                       -0.000528
# var38                                         0.001727
# TARGET                                       -0.004257
#
#                                imp_op_var40_efect_ult1  imp_op_var40_ult1  \
# ID                                           -0.022529          -0.039346
# var3                                          0.001009           0.001466
# var15                                         0.004373           0.043716
# imp_ent_var16_ult1                           -0.001479           0.082766
# imp_op_var39_comer_ult1                       0.008400           0.322856
# imp_op_var39_comer_ult3                       0.004658           0.325530
# imp_op_var40_comer_ult1                       0.005403           0.826481
# imp_op_var40_comer_ult3                       0.003413           0.816750
# imp_op_var40_efect_ult1                       1.000000           0.521698
# imp_op_var40_ult1                             0.521698           1.000000
# imp_op_var41_comer_ult1                       0.006990           0.021079
# imp_op_var41_comer_ult3                       0.003777           0.047866
# imp_op_var41_efect_ult1                       0.268865           0.146138
# imp_op_var41_efect_ult3                       0.180165           0.103947
# imp_op_var41_ult1                             0.180993           0.108290
# imp_op_var39_efect_ult1                       0.469647           0.250396
# imp_op_var39_efect_ult3                       0.329211           0.181306
# imp_op_var39_ult1                             0.306273           0.363433
# imp_sal_var16_ult1                           -0.000690          -0.001000
# ind_var1_0                                    0.200753           0.291173
# ind_var1                                      0.333219           0.483303
# ind_var5_0                                   -0.025554          -0.007611
# ind_var5                                      0.001877           0.015373
# ind_var8_0                                    0.029394           0.001311
# ind_var8                                      0.031547           0.002043
# ind_var12_0                                  -0.005568           0.033330
# ind_var12                                    -0.004478           0.043749
# ind_var13_0                                  -0.004859           0.029300
# ind_var13_corto_0                            -0.004405          -0.000596
# ind_var13_corto                              -0.004331          -0.000398
# ...                                                ...                ...
# saldo_medio_var8_ult1                         0.003710           0.003539
# saldo_medio_var8_ult3                         0.003934           0.003779
# saldo_medio_var12_hace2                      -0.001673           0.040998
# saldo_medio_var12_hace3                      -0.001441          -0.002089
# saldo_medio_var12_ult1                       -0.002112           0.059795
# saldo_medio_var12_ult3                       -0.002240           0.068967
# saldo_medio_var13_corto_hace2                -0.002971          -0.004309
# saldo_medio_var13_corto_hace3                -0.001536          -0.002228
# saldo_medio_var13_corto_ult1                 -0.003176          -0.004219
# saldo_medio_var13_corto_ult3                 -0.003138          -0.004073
# saldo_medio_var13_largo_hace2                -0.001153           0.044380
# saldo_medio_var13_largo_hace3                -0.000608           0.002591
# saldo_medio_var13_largo_ult1                 -0.001323           0.035378
# saldo_medio_var13_largo_ult3                 -0.001297           0.028663
# saldo_medio_var13_medio_hace2                -0.000291           0.000323
# saldo_medio_var13_medio_ult3                 -0.000291           0.000323
# saldo_medio_var17_hace2                      -0.000363          -0.000527
# saldo_medio_var17_hace3                      -0.000373          -0.000541
# saldo_medio_var17_ult1                       -0.000341          -0.000495
# saldo_medio_var17_ult3                       -0.000353          -0.000512
# saldo_medio_var33_hace2                      -0.000315          -0.000456
# saldo_medio_var33_hace3                      -0.000291          -0.000422
# saldo_medio_var33_ult1                       -0.000413          -0.000599
# saldo_medio_var33_ult3                       -0.000416          -0.000603
# saldo_medio_var44_hace2                      -0.000291          -0.000422
# saldo_medio_var44_hace3                      -0.000291          -0.000422
# saldo_medio_var44_ult1                       -0.000396          -0.000574
# saldo_medio_var44_ult3                       -0.000414          -0.000600
# var38                                        -0.000256           0.002080
# TARGET                                        0.025827          -0.006140
#
#                                ...  saldo_medio_var33_hace2  \
# ID                             ...                 0.000732
# var3                           ...                 0.000772
# var15                          ...                 0.036132
# imp_ent_var16_ult1             ...                -0.001744
# imp_op_var39_comer_ult1        ...                -0.003273
# imp_op_var39_comer_ult3        ...                -0.003288
# imp_op_var40_comer_ult1        ...                -0.000395
# imp_op_var40_comer_ult3        ...                -0.000402
# imp_op_var40_efect_ult1        ...                -0.000315
# imp_op_var40_ult1              ...                -0.000456
# imp_op_var41_comer_ult1        ...                -0.003408
# imp_op_var41_comer_ult3        ...                -0.003416
# imp_op_var41_efect_ult1        ...                -0.002573
# imp_op_var41_efect_ult3        ...                -0.002826
# imp_op_var41_ult1              ...                -0.003528
# imp_op_var39_efect_ult1        ...                -0.002428
# imp_op_var39_efect_ult3        ...                -0.002762
# imp_op_var39_ult1              ...                -0.003426
# imp_sal_var16_ult1             ...                -0.000512
# ind_var1_0                     ...                -0.001567
# ind_var1                       ...                -0.000944
# ind_var5_0                     ...                -0.066146
# ind_var5                       ...                -0.018865
# ind_var8_0                     ...                -0.002894
# ind_var8                       ...                -0.002725
# ind_var12_0                    ...                -0.004136
# ind_var12                      ...                -0.003326
# ind_var13_0                    ...                 0.000775
# ind_var13_corto_0              ...                 0.001520
# ind_var13_corto                ...                 0.001650
# ...                            ...                      ...
# saldo_medio_var8_ult1          ...                -0.001387
# saldo_medio_var8_ult3          ...                -0.001288
# saldo_medio_var12_hace2        ...                -0.001243
# saldo_medio_var12_hace3        ...                -0.001070
# saldo_medio_var12_ult1         ...                -0.001569
# saldo_medio_var12_ult3         ...                -0.001664
# saldo_medio_var13_corto_hace2  ...                -0.001601
# saldo_medio_var13_corto_hace3  ...                -0.001141
# saldo_medio_var13_corto_ult1   ...                -0.001591
# saldo_medio_var13_corto_ult3   ...                -0.001550
# saldo_medio_var13_largo_hace2  ...                -0.000857
# saldo_medio_var13_largo_hace3  ...                -0.000451
# saldo_medio_var13_largo_ult1   ...                -0.000983
# saldo_medio_var13_largo_ult3   ...                -0.000963
# saldo_medio_var13_medio_hace2  ...                -0.000216
# saldo_medio_var13_medio_ult3   ...                -0.000216
# saldo_medio_var17_hace2        ...                -0.000270
# saldo_medio_var17_hace3        ...                -0.000277
# saldo_medio_var17_ult1         ...                -0.000253
# saldo_medio_var17_ult3         ...                -0.000262
# saldo_medio_var33_hace2        ...                 1.000000
# saldo_medio_var33_hace3        ...                 0.997495
# saldo_medio_var33_ult1         ...                 0.703017
# saldo_medio_var33_ult3         ...                 0.765048
# saldo_medio_var44_hace2        ...                -0.000216
# saldo_medio_var44_hace3        ...                -0.000216
# saldo_medio_var44_ult1         ...                -0.000294
# saldo_medio_var44_ult3         ...                -0.000307
# var38                          ...                 0.011890
# TARGET                         ...                -0.003145
#
#                                saldo_medio_var33_hace3  \
# ID                                            0.001018
# var3                                          0.000716
# var15                                         0.034025
# imp_ent_var16_ult1                           -0.001613
# imp_op_var39_comer_ult1                      -0.003028
# imp_op_var39_comer_ult3                      -0.003042
# imp_op_var40_comer_ult1                      -0.000365
# imp_op_var40_comer_ult3                      -0.000372
# imp_op_var40_efect_ult1                      -0.000291
# imp_op_var40_ult1                            -0.000422
# imp_op_var41_comer_ult1                      -0.003153
# imp_op_var41_comer_ult3                      -0.003161
# imp_op_var41_efect_ult1                      -0.002380
# imp_op_var41_efect_ult3                      -0.002615
# imp_op_var41_ult1                            -0.003264
# imp_op_var39_efect_ult1                      -0.002247
# imp_op_var39_efect_ult3                      -0.002555
# imp_op_var39_ult1                            -0.003169
# imp_sal_var16_ult1                           -0.000474
# ind_var1_0                                   -0.001450
# ind_var1                                     -0.000874
# ind_var5_0                                   -0.066562
# ind_var5                                     -0.019758
# ind_var8_0                                   -0.002678
# ind_var8                                     -0.002521
# ind_var12_0                                  -0.003826
# ind_var12                                    -0.003077
# ind_var13_0                                  -0.003339
# ind_var13_corto_0                            -0.003027
# ind_var13_corto                              -0.002976
# ...                                                ...
# saldo_medio_var8_ult1                        -0.001283
# saldo_medio_var8_ult3                        -0.001192
# saldo_medio_var12_hace2                      -0.001150
# saldo_medio_var12_hace3                      -0.000990
# saldo_medio_var12_ult1                       -0.001452
# saldo_medio_var12_ult3                       -0.001540
# saldo_medio_var13_corto_hace2                -0.002042
# saldo_medio_var13_corto_hace3                -0.001055
# saldo_medio_var13_corto_ult1                 -0.002182
# saldo_medio_var13_corto_ult3                 -0.002156
# saldo_medio_var13_largo_hace2                -0.000793
# saldo_medio_var13_largo_hace3                -0.000418
# saldo_medio_var13_largo_ult1                 -0.000909
# saldo_medio_var13_largo_ult3                 -0.000891
# saldo_medio_var13_medio_hace2                -0.000200
# saldo_medio_var13_medio_ult3                 -0.000200
# saldo_medio_var17_hace2                      -0.000250
# saldo_medio_var17_hace3                      -0.000256
# saldo_medio_var17_ult1                       -0.000234
# saldo_medio_var17_ult3                       -0.000243
# saldo_medio_var33_hace2                       0.997495
# saldo_medio_var33_hace3                       1.000000
# saldo_medio_var33_ult1                        0.651954
# saldo_medio_var33_ult3                        0.718421
# saldo_medio_var44_hace2                      -0.000200
# saldo_medio_var44_hace3                      -0.000200
# saldo_medio_var44_ult1                       -0.000272
# saldo_medio_var44_ult3                       -0.000284
# var38                                         0.011616
# TARGET                                       -0.002910
#
#                                saldo_medio_var33_ult1  saldo_medio_var33_ult3  \
# ID                                          -0.003391               -0.002944
# var3                                         0.000999                0.001008
# var15                                        0.043951                0.044511
# imp_ent_var16_ult1                          -0.002290               -0.002305
# imp_op_var39_comer_ult1                     -0.004300               -0.004328
# imp_op_var39_comer_ult3                     -0.004319               -0.004348
# imp_op_var40_comer_ult1                     -0.000519               -0.000522
# imp_op_var40_comer_ult3                     -0.000528               -0.000531
# imp_op_var40_efect_ult1                     -0.000413               -0.000416
# imp_op_var40_ult1                           -0.000599               -0.000603
# imp_op_var41_comer_ult1                     -0.004476               -0.004506
# imp_op_var41_comer_ult3                     -0.004487               -0.004517
# imp_op_var41_efect_ult1                     -0.003379               -0.003402
# imp_op_var41_efect_ult3                     -0.003712               -0.003737
# imp_op_var41_ult1                           -0.004634               -0.004665
# imp_op_var39_efect_ult1                     -0.003190               -0.003211
# imp_op_var39_efect_ult3                     -0.003628               -0.003652
# imp_op_var39_ult1                           -0.004500               -0.004530
# imp_sal_var16_ult1                          -0.000673               -0.000677
# ind_var1_0                                  -0.002058               -0.002072
# ind_var1                                    -0.001240               -0.001248
# ind_var5_0                                  -0.041099               -0.045694
# ind_var5                                    -0.005113               -0.007003
# ind_var8_0                                  -0.003801               -0.003827
# ind_var8                                    -0.003580               -0.003603
# ind_var12_0                                 -0.005432               -0.005469
# ind_var12                                   -0.004369               -0.004398
# ind_var13_0                                  0.043211                0.039211
# ind_var13_corto_0                            0.048102                0.043737
# ind_var13_corto                              0.048994                0.044561
# ...                                               ...                     ...
# saldo_medio_var8_ult1                       -0.001821               -0.001833
# saldo_medio_var8_ult3                       -0.001692               -0.001704
# saldo_medio_var12_hace2                     -0.001632               -0.001643
# saldo_medio_var12_hace3                     -0.001406               -0.001415
# saldo_medio_var12_ult1                      -0.002061               -0.002075
# saldo_medio_var12_ult3                      -0.002186               -0.002200
# saldo_medio_var13_corto_hace2                0.003726                0.003159
# saldo_medio_var13_corto_hace3               -0.001498               -0.001508
# saldo_medio_var13_corto_ult1                 0.005302                0.004586
# saldo_medio_var13_corto_ult3                 0.005477                0.004750
# saldo_medio_var13_largo_hace2               -0.001125               -0.001133
# saldo_medio_var13_largo_hace3               -0.000593               -0.000597
# saldo_medio_var13_largo_ult1                -0.001291               -0.001300
# saldo_medio_var13_largo_ult3                -0.001265               -0.001274
# saldo_medio_var13_medio_hace2               -0.000284               -0.000286
# saldo_medio_var13_medio_ult3                -0.000284               -0.000286
# saldo_medio_var17_hace2                     -0.000354               -0.000357
# saldo_medio_var17_hace3                     -0.000364               -0.000366
# saldo_medio_var17_ult1                      -0.000333               -0.000335
# saldo_medio_var17_ult3                      -0.000344               -0.000347
# saldo_medio_var33_hace2                      0.703017                0.765048
# saldo_medio_var33_hace3                      0.651954                0.718421
# saldo_medio_var33_ult1                       1.000000                0.995805
# saldo_medio_var33_ult3                       0.995805                1.000000
# saldo_medio_var44_hace2                     -0.000284               -0.000286
# saldo_medio_var44_hace3                     -0.000284               -0.000286
# saldo_medio_var44_ult1                      -0.000386               -0.000389
# saldo_medio_var44_ult3                      -0.000404               -0.000406
# var38                                        0.008952                0.009698
# TARGET                                      -0.004131               -0.004158
#
#                                saldo_medio_var44_hace2  \
# ID                                           -0.023540
# var3                                          0.000729
# var15                                         0.016390
# imp_ent_var16_ult1                           -0.001613
# imp_op_var39_comer_ult1                      -0.003028
# imp_op_var39_comer_ult3                      -0.003042
# imp_op_var40_comer_ult1                      -0.000365
# imp_op_var40_comer_ult3                      -0.000372
# imp_op_var40_efect_ult1                      -0.000291
# imp_op_var40_ult1                            -0.000422
# imp_op_var41_comer_ult1                      -0.003153
# imp_op_var41_comer_ult3                      -0.003161
# imp_op_var41_efect_ult1                      -0.002380
# imp_op_var41_efect_ult3                      -0.002615
# imp_op_var41_ult1                            -0.003264
# imp_op_var39_efect_ult1                      -0.002247
# imp_op_var39_efect_ult3                      -0.002555
# imp_op_var39_ult1                            -0.003169
# imp_sal_var16_ult1                           -0.000474
# ind_var1_0                                   -0.001450
# ind_var1                                     -0.000874
# ind_var5_0                                    0.003005
# ind_var5                                      0.010124
# ind_var8_0                                   -0.002678
# ind_var8                                     -0.002521
# ind_var12_0                                  -0.003826
# ind_var12                                    -0.003077
# ind_var13_0                                  -0.003339
# ind_var13_corto_0                            -0.003027
# ind_var13_corto                              -0.002976
# ...                                                ...
# saldo_medio_var8_ult1                        -0.001283
# saldo_medio_var8_ult3                        -0.001192
# saldo_medio_var12_hace2                      -0.001150
# saldo_medio_var12_hace3                      -0.000990
# saldo_medio_var12_ult1                       -0.001452
# saldo_medio_var12_ult3                       -0.001540
# saldo_medio_var13_corto_hace2                -0.002042
# saldo_medio_var13_corto_hace3                -0.001055
# saldo_medio_var13_corto_ult1                 -0.002182
# saldo_medio_var13_corto_ult3                 -0.002156
# saldo_medio_var13_largo_hace2                -0.000793
# saldo_medio_var13_largo_hace3                -0.000418
# saldo_medio_var13_largo_ult1                 -0.000909
# saldo_medio_var13_largo_ult3                 -0.000891
# saldo_medio_var13_medio_hace2                -0.000200
# saldo_medio_var13_medio_ult3                 -0.000200
# saldo_medio_var17_hace2                      -0.000250
# saldo_medio_var17_hace3                      -0.000256
# saldo_medio_var17_ult1                       -0.000234
# saldo_medio_var17_ult3                       -0.000243
# saldo_medio_var33_hace2                      -0.000216
# saldo_medio_var33_hace3                      -0.000200
# saldo_medio_var33_ult1                       -0.000284
# saldo_medio_var33_ult3                       -0.000286
# saldo_medio_var44_hace2                       1.000000
# saldo_medio_var44_hace3                       1.000000
# saldo_medio_var44_ult1                        0.935628
# saldo_medio_var44_ult3                        0.901569
# var38                                         0.020713
# TARGET                                       -0.002910
#
#                                saldo_medio_var44_hace3  \
# ID                                           -0.023540
# var3                                          0.000729
# var15                                         0.016390
# imp_ent_var16_ult1                           -0.001613
# imp_op_var39_comer_ult1                      -0.003028
# imp_op_var39_comer_ult3                      -0.003042
# imp_op_var40_comer_ult1                      -0.000365
# imp_op_var40_comer_ult3                      -0.000372
# imp_op_var40_efect_ult1                      -0.000291
# imp_op_var40_ult1                            -0.000422
# imp_op_var41_comer_ult1                      -0.003153
# imp_op_var41_comer_ult3                      -0.003161
# imp_op_var41_efect_ult1                      -0.002380
# imp_op_var41_efect_ult3                      -0.002615
# imp_op_var41_ult1                            -0.003264
# imp_op_var39_efect_ult1                      -0.002247
# imp_op_var39_efect_ult3                      -0.002555
# imp_op_var39_ult1                            -0.003169
# imp_sal_var16_ult1                           -0.000474
# ind_var1_0                                   -0.001450
# ind_var1                                     -0.000874
# ind_var5_0                                    0.003005
# ind_var5                                      0.010124
# ind_var8_0                                   -0.002678
# ind_var8                                     -0.002521
# ind_var12_0                                  -0.003826
# ind_var12                                    -0.003077
# ind_var13_0                                  -0.003339
# ind_var13_corto_0                            -0.003027
# ind_var13_corto                              -0.002976
# ...                                                ...
# saldo_medio_var8_ult1                        -0.001283
# saldo_medio_var8_ult3                        -0.001192
# saldo_medio_var12_hace2                      -0.001150
# saldo_medio_var12_hace3                      -0.000990
# saldo_medio_var12_ult1                       -0.001452
# saldo_medio_var12_ult3                       -0.001540
# saldo_medio_var13_corto_hace2                -0.002042
# saldo_medio_var13_corto_hace3                -0.001055
# saldo_medio_var13_corto_ult1                 -0.002182
# saldo_medio_var13_corto_ult3                 -0.002156
# saldo_medio_var13_largo_hace2                -0.000793
# saldo_medio_var13_largo_hace3                -0.000418
# saldo_medio_var13_largo_ult1                 -0.000909
# saldo_medio_var13_largo_ult3                 -0.000891
# saldo_medio_var13_medio_hace2                -0.000200
# saldo_medio_var13_medio_ult3                 -0.000200
# saldo_medio_var17_hace2                      -0.000250
# saldo_medio_var17_hace3                      -0.000256
# saldo_medio_var17_ult1                       -0.000234
# saldo_medio_var17_ult3                       -0.000243
# saldo_medio_var33_hace2                      -0.000216
# saldo_medio_var33_hace3                      -0.000200
# saldo_medio_var33_ult1                       -0.000284
# saldo_medio_var33_ult3                       -0.000286
# saldo_medio_var44_hace2                       1.000000
# saldo_medio_var44_hace3                       1.000000
# saldo_medio_var44_ult1                        0.935628
# saldo_medio_var44_ult3                        0.901569
# var38                                         0.020713
# TARGET                                       -0.002910
#
#                                saldo_medio_var44_ult1  saldo_medio_var44_ult3  \
# ID                                          -0.027520               -0.027959
# var3                                         0.000976                0.001018
# var15                                        0.029779                0.032479
# imp_ent_var16_ult1                          -0.002193               -0.002293
# imp_op_var39_comer_ult1                     -0.004117               -0.004304
# imp_op_var39_comer_ult3                     -0.004136               -0.004324
# imp_op_var40_comer_ult1                     -0.000497               -0.000519
# imp_op_var40_comer_ult3                     -0.000505               -0.000528
# imp_op_var40_efect_ult1                     -0.000396               -0.000414
# imp_op_var40_ult1                           -0.000574               -0.000600
# imp_op_var41_comer_ult1                     -0.004287               -0.004481
# imp_op_var41_comer_ult3                     -0.004297               -0.004492
# imp_op_var41_efect_ult1                     -0.003236               -0.003383
# imp_op_var41_efect_ult3                     -0.003555               -0.003716
# imp_op_var41_ult1                           -0.004438               -0.004639
# imp_op_var39_efect_ult1                     -0.003055               -0.003193
# imp_op_var39_efect_ult3                     -0.003474               -0.003632
# imp_op_var39_ult1                           -0.004309               -0.004504
# imp_sal_var16_ult1                          -0.000644               -0.000674
# ind_var1_0                                  -0.001971               -0.002061
# ind_var1                                    -0.001188               -0.001241
# ind_var5_0                                   0.004086                0.004271
# ind_var5                                     0.013765                0.014389
# ind_var8_0                                  -0.003640               -0.003805
# ind_var8                                    -0.003428               -0.003583
# ind_var12_0                                 -0.005202               -0.005438
# ind_var12                                   -0.004184               -0.004374
# ind_var13_0                                 -0.004540               -0.004746
# ind_var13_corto_0                           -0.004116               -0.004302
# ind_var13_corto                             -0.004046               -0.004230
# ...                                               ...                     ...
# saldo_medio_var8_ult1                       -0.001744               -0.001823
# saldo_medio_var8_ult3                       -0.001621               -0.001694
# saldo_medio_var12_hace2                     -0.001563               -0.001634
# saldo_medio_var12_hace3                     -0.001346               -0.001407
# saldo_medio_var12_ult1                      -0.001974               -0.002063
# saldo_medio_var12_ult3                      -0.002093               -0.002188
# saldo_medio_var13_corto_hace2               -0.002776               -0.002902
# saldo_medio_var13_corto_hace3               -0.001435               -0.001500
# saldo_medio_var13_corto_ult1                -0.002967               -0.003102
# saldo_medio_var13_corto_ult3                -0.002932               -0.003065
# saldo_medio_var13_largo_hace2               -0.001078               -0.001126
# saldo_medio_var13_largo_hace3               -0.000568               -0.000594
# saldo_medio_var13_largo_ult1                -0.001236               -0.001292
# saldo_medio_var13_largo_ult3                -0.001212               -0.001267
# saldo_medio_var13_medio_hace2               -0.000272               -0.000284
# saldo_medio_var13_medio_ult3                -0.000272               -0.000284
# saldo_medio_var17_hace2                     -0.000339               -0.000355
# saldo_medio_var17_hace3                     -0.000349               -0.000364
# saldo_medio_var17_ult1                      -0.000319               -0.000333
# saldo_medio_var17_ult3                      -0.000330               -0.000345
# saldo_medio_var33_hace2                     -0.000294               -0.000307
# saldo_medio_var33_hace3                     -0.000272               -0.000284
# saldo_medio_var33_ult1                      -0.000386               -0.000404
# saldo_medio_var33_ult3                      -0.000389               -0.000406
# saldo_medio_var44_hace2                      0.935628                0.901569
# saldo_medio_var44_hace3                      0.935628                0.901569
# saldo_medio_var44_ult1                       1.000000                0.996248
# saldo_medio_var44_ult3                       0.996248                1.000000
# var38                                        0.021925                0.021794
# TARGET                                      -0.003956               -0.004135
#
#                                   var38    TARGET
# ID                             0.007020 -0.019668
# var3                           0.000151  0.010090
# var15                         -0.000726  0.095293
# imp_ent_var16_ult1            -0.003075 -0.019536
# imp_op_var39_comer_ult1        0.024544 -0.001839
# imp_op_var39_comer_ult3        0.025798 -0.000662
# imp_op_var40_comer_ult1        0.003467 -0.003591
# imp_op_var40_comer_ult3        0.001727 -0.004257
# imp_op_var40_efect_ult1       -0.000256  0.025827
# imp_op_var40_ult1              0.002080 -0.006140
# imp_op_var41_comer_ult1        0.025353 -0.000567
# imp_op_var41_comer_ult3        0.027336  0.000872
# imp_op_var41_efect_ult1       -0.006546  0.034291
# imp_op_var41_efect_ult3       -0.001114  0.032954
# imp_op_var41_ult1              0.009318  0.022447
# imp_op_var39_efect_ult1       -0.006057  0.037196
# imp_op_var39_efect_ult3       -0.001109  0.035671
# imp_op_var39_ult1              0.009277  0.019428
# imp_sal_var16_ult1             0.014230 -0.006894
# ind_var1_0                     0.012940  0.008878
# ind_var1                       0.015615  0.020235
# ind_var5_0                     0.001614 -0.036039
# ind_var5                      -0.030030 -0.139648
# ind_var8_0                    -0.007348  0.049770
# ind_var8                      -0.011075  0.045441
# ind_var12_0                    0.011410 -0.051634
# ind_var12                      0.014296 -0.039881
# ind_var13_0                    0.007024 -0.044038
# ind_var13_corto_0              0.004480 -0.039076
# ind_var13_corto                0.004204 -0.038258
# ...                                 ...       ...
# saldo_medio_var8_ult1         -0.005706 -0.002719
# saldo_medio_var8_ult3         -0.007583 -0.002373
# saldo_medio_var12_hace2        0.024869 -0.016722
# saldo_medio_var12_hace3        0.017157 -0.014399
# saldo_medio_var12_ult1         0.022917 -0.019003
# saldo_medio_var12_ult3         0.023255 -0.019440
# saldo_medio_var13_corto_hace2  0.006801 -0.028936
# saldo_medio_var13_corto_hace3  0.012959 -0.015352
# saldo_medio_var13_corto_ult1   0.004177 -0.030860
# saldo_medio_var13_corto_ult3   0.003774 -0.030436
# saldo_medio_var13_largo_hace2  0.010747 -0.011527
# saldo_medio_var13_largo_hace3  0.003341 -0.006074
# saldo_medio_var13_largo_ult1   0.014147 -0.013227
# saldo_medio_var13_largo_ult3   0.012421 -0.012963
# saldo_medio_var13_medio_hace2 -0.005251 -0.002910
# saldo_medio_var13_medio_ult3  -0.005251 -0.002910
# saldo_medio_var17_hace2        0.012394 -0.003630
# saldo_medio_var17_hace3        0.013786 -0.003729
# saldo_medio_var17_ult1        -0.002360  0.067798
# saldo_medio_var17_ult3        -0.000873  0.067168
# saldo_medio_var33_hace2        0.011890 -0.003145
# saldo_medio_var33_hace3        0.011616 -0.002910
# saldo_medio_var33_ult1         0.008952 -0.004131
# saldo_medio_var33_ult3         0.009698 -0.004158
# saldo_medio_var44_hace2        0.020713 -0.002910
# saldo_medio_var44_hace3        0.020713 -0.002910
# saldo_medio_var44_ult1         0.021925 -0.003956
# saldo_medio_var44_ult3         0.021794 -0.004135
# var38                          1.000000 -0.022161
# TARGET                        -0.022161  1.000000
#
# [252 rows x 252 columns]

# %% [markdown]
# <h3>What data is in target column?</h3>

# %%
# What is in target column
train_data.TARGET.value_counts()
#if training is done only on negative rewiews(1), and if doest apply to neg model is true maybe it is better for model?
# Out:
# 0    4797
# 1     203
# Name: TARGET, dtype: int64

# %% [markdown]
# <p>They are little of unhappy clients</p>

# %% [markdown]
# <h4>We need to split data to train, test, and validation for later use</h4>

# %%
# %%time
#Spliting to Train, test, valid
df_train = train_data[:3000] 
df_test = train_data[3000:4000]
# Model will not see valid data set 
df_valid = train_data[4000:]
print(df_train.shape, df_test.shape, df_valid.shape)
# Out:
# (3000, 252) (1000, 252) (1000, 252)
# CPU times: user 3.27 ms, sys: 0 ns, total: 3.27 ms
# Wall time: 3.18 ms

# %% [markdown]
# <h4>Droping ID, and TARGET columns from data</h4>

# %%
# %time
# Training data
X_train = df_train.drop(['ID', 'TARGET'], axis=1)
y_train = df_train.TARGET
# Test data
X_test = df_test.drop(['ID', 'TARGET'], axis=1)
y_test = df_test.TARGET
# Validation data
X_valid = df_valid.drop(['ID', 'TARGET'], axis=1)
y_valid = df_valid.TARGET
# submision data
data_for_sub = test_data.drop(['ID'], axis=1)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 6.68 µs

# %% [markdown]
# <h3>Initializing models for training</h3>

# %%
xgb = xgb.XGBRFRegressor()
tree = ensemble.RandomForestRegressor()
ada = ensemble.AdaBoostRegressor()
grad = ensemble.GradientBoostingRegressor()

# %%
import scipy as sp

def get_scores_and_params(pipeline, params):
   

    search = RandomizedSearchCV(pipeline, 
    params, cv=3, n_iter=5, scoring="roc_auc",
                                    n_jobs=-1,
                                    verbose=2)
    search.fit(X_train, y_train)
    return search.best_score_, search.best_params_

# %% [markdown]
# <h3>Creating Pipelines for model selection</h3>

# %%
pipelines = [Pipeline([('xgb', xgb)]), 
             Pipeline([('tree', tree)]), 
             Pipeline([('ada', ada)]),
             Pipeline([('grad', grad)])]
getd = [
{'xgb__max_depth': sp.stats.randint(1, 11),
'xgb__n_estimators': [100, 200, 500, 1000],
'xgb__colsample_bytree': [0.5,0.6,0.7,0.8]}
        
,{'tree__n_estimators': [100, 200, 500, 1000],
  'tree__min_samples_split':[2, 4, 8, 10],
  'tree__min_samples_leaf': [1, 2, 3, 4]}

,{'ada__learning_rate': [0.3, 0.4,0.5,0.7,1],
  'ada__n_estimators': [10, 50, 100, 500]}
    
,{'grad__learning_rate': [0.1,0.2,0.5,1],
  'grad__max_depth': [3,5,7],
  'grad__n_estimators': [1, 2, 3, 4]}
]
warnings.filterwarnings('ignore')

for i in range(len(pipelines)):
    print(get_scores_and_params(pipelines[i], getd[i]))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   39.3s finished
# [00:59:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# (0.7418845290786579, {'xgb__colsample_bytree': 0.6, 'xgb__n_estimators': 1000, 'xgb__max_depth': 5})
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:   58.7s finished
# (0.7373133084804664, {'tree__min_samples_split': 4, 'tree__min_samples_leaf': 3, 'tree__n_estimators': 200})
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.8s finished
# (0.7755887807476303, {'ada__n_estimators': 500, 'ada__learning_rate': 0.5})
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    0.8s finished
# (0.7464795742537433, {'grad__max_depth': 7, 'grad__n_estimators': 4, 'grad__learning_rate': 0.2})

# %% [markdown]
# <h3>What are most important features for this model?</h3>

# %% [markdown]
# <p>AdaBoostRegressor scored best, let use it</p>

# %%
#%time
## # Feature selection
# Classifier runs faster
clf = ensemble.AdaBoostRegressor(n_estimators=500, learning_rate=0.5)
selector = clf.fit(X_train, y_train)

# plot most important features
feat_imp = pd.Series(clf.feature_importances_, index = X_train.columns.values).sort_values(ascending=False)
feat_imp[:40].plot(kind='bar', title='Feature Importances according to AdaBoostRegressor', figsize=(12, 8))
plt.ylabel('Feature Importance Score')
plt.subplots_adjust(bottom=0.3)
plt.show()

# %% [markdown]
# <p>List of important features</p>

# %%
# features to fit model
features = feat_imp[:40].index
print(features)
# Out:
# Index(['var15', 'saldo_medio_var5_hace2', 'saldo_var30', 'var38',
#        'saldo_medio_var5_ult3', 'num_op_var41_hace3', 'num_var30_0',
#        'num_meses_var5_ult3', 'num_aport_var17_ult1', 'var36',
#        'num_var45_hace3', 'num_var45_ult3', 'saldo_medio_var5_ult1',
#        'num_var5_0', 'var3', 'num_var22_hace3', 'imp_trans_var37_ult1',
#        'num_var45_ult1', 'num_op_var41_hace2', 'ind_var8_0',
#        'saldo_medio_var5_hace3', 'imp_op_var39_efect_ult3', 'num_var8_0',
#        'ind_var43_recib_ult1', 'num_var41_0', 'ind_var39_0', 'saldo_var8',
#        'ind_var41_0', 'num_var45_hace2', 'saldo_var5',
#        'num_meses_var39_vig_ult3', 'ind_var8', 'num_var20_0',
#        'imp_op_var40_comer_ult3', 'num_op_var40_ult3', 'num_op_var40_ult1',
#        'num_op_var40_hace3', 'num_op_var40_hace2', 'num_var25_0',
#        'num_var26_0'],
#       dtype='object')

# %%
# mount new selected features
X_train = X_train[features]
X_test = X_test[features]
X_valid = X_valid[features]

# %% [markdown]
# <h3>Plot 5 most import features values</h3>

# %%
# plot first 5 most important features
for i in features[0:5]:
   
    #train_data[i].value_counts().mean()
    x = train_data[i].value_counts().head().index
    y = train_data[i].value_counts().head()
    
    plt.figure()
    plt.scatter(y, x)

    plt.xlabel(i)

# %% [markdown]
# <h3>Fiting and submmiting for competition</h3>

# %%
clf.fit(X_train, y_train)
preds = clf.predict(X_test)
val_pred = clf.predict(X_valid)
roc_auc_score(y_test, preds), roc_auc_score(y_valid, val_pred)
# Out:
# (0.8491819341901377, 0.7627871670648121)

# %%
pros = clf.predict(data_for_sub[features])

# %%
# submission
sub = pd.DataFrame()
sub['ID'] = test_data['ID']
sub['target'] = pros
sub.to_csv('submission.csv',index=False)
# distribution of values
test = pd.read_csv('submission.csv')
test.head()
# Out:
#    ID    target
# 0   2  0.190083
# 1   5  0.190083
# 2   6  0.016058
# 3   7  0.046875
# 4   9  0.016058
